# %%
# Integers: Addition Example
# Addition
sum = 3 + 7

# Result: print the sum
# To show a variable, we use the print() function
print(sum)
# Out:
# 10

# %%
# Integers: Subtraction Example
# Subtraction
min = 10 - 4

# Result: print the subtraction
# To show a variable, we use the print() function
print(min)
# Out:
# 6

# %%
# Integers: Multiplication Example
# Multiplication
mul = 4 * 6

# Result: print the multiplication
# To show a variable, we use the print() function
print(mul)
# Out:
# 24

# %%
# Integers: Division Example
# Division
div = 20 / 5

# Result: print the division
# To show a variable, we use the print() function
print(div)
# Out:
# 4.0

# %%
## Strings
# If we want to store text, we use strings.
# We can create strings by inserting an ''='' and consequently the text is going to b in the middle of ' '
name1 = 'Pasquale'
# We can use also double quotes " "
secondName = "Riccardo"

name1 = "Pasquale"

# To show a string, we use the print() function
print(secondName)
print(name1)
# Out:
# Riccardo
# Pasquale

# %%
# We can include strings and Integers in a single print statement

names = "Pasquale, Renato, Veronica"
var1 = 24
var2 = 20
var3 = 15

print("We are" ,names, "and we are", var1, var2, var3, "years old.")
# Out:
# We are Pasquale, Renato, Veronica and we are 24 20 15 years old.

# %%
# We can also check the type of item we're typing, by using the type() function.
name5 = 'Hello'
age = 15

print(type(name5))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Lists and Indexables Integers and Strings
vegetables = ["carrot", "broccoli", "spinach", "cauliflower", "bellpepper", "lettuce", "cabbage"]
# If we want to print a specific item from the list, we can index them, by using [] and inserting the number, as the position the item has in the list.
print(vegetables[0])
# Out:
# carrot

# %%
# Augmented Assignment Operators
# We can use augmented assignment operators to modify the value of a variable in a more concise way.
# For example, instead of writing ab = ab + 3, we can use the += operator to achieve the same result.
ab = 5
ab += 3 
ab += 4
print (ab)

# Another example with subtraction
bc = 10
bc -= 2
bc -= 3
print(bc)

# Another example with multiplication
cd = 4
cd *= 3
cd *= 2
print(cd)

# Another example with division
de = 20
de /= 4
de /= 2
print(de)
# Out:
# 12
# 5
# 24
# 2.5

# %%
# Lists
# Lists are a collection of items that can be of different types, such as integers, strings, or even other lists.
# We can create a list by using square brackets [] and separating the items with commas.
my_list = [1, 2, 3, "hello", "world"] #As you can see, the list can contain both inegers, strings and even other types of items.

# We can access the items in a list by using their index, which starts at 0.
print(my_list[0]) # This will print the first item in the list, which is, in this case, the integer 1.

# We can also use negative numbers to index lists.
print(my_list[-1]) # This will print the last item in the list, which is, in this case, the string "world".

# We can also create some "nested" lists, so you can assign some items to other items in the list.
# For instance:
bed = 1.56
kit = 2.34
bath = 6.42
gard = 15.13 # we want to assign to each of these listed variables, a name.


house = [
    ["bedroom", bed],
    ["kitchen", kit],
    ["bathroom", bath],
    ["garden", gard]
]

print(house) # In this case, it will print a list with 4 items, each of them have a name and an integer assigned to it.
# Out:
# 1
# world
# [['bedroom', 1.56], ['kitchen', 2.34], ['bathroom', 6.42], ['garden', 15.13]]

# %%
# Update the value of an item to the list.
areas = [
    "hallway", 11.25,
    "kitchen", 18.0,
    "living room", 20.0,
    "bedroom", 10.75,
    "bathroom", 9.50
]

# For this list, we want to change the value of the bathroom area.
areas[-1] = 10.50 # We can do this by indexing the item we want to change and assigning it a new value.
print(areas) # by printing the list, it will show the updated version.
# This because the list is being used as a ''type'' of value, and whenever we change the valuse that are in the list, it will update them automatically..
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]

# %%
# Add another item to the list.
# There are three ways to add an item:
# 1. Using the append() function
areas.append("pool")
print(areas) # by printing the list, it will show the updated version.
# In this case, you will be able to add only one item at a time, but if you want to add more than one item.

# 2. Using the extend() function
areas.extend(["garage", 12.0]) # This will add both the name and the value of the garage to the list.
print(areas) # by printing the list, it will show the updated version.

# 3. Using the mathematical operator +
areas_1 = areas + ["garden", 26.45]
print(areas_1) # by printing the list, it will show the updated version.
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'pool']
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'pool', 'garage', 12.0]
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'pool', 'garage', 12.0, 'garden', 26.45]

# %%
# Remove an item from the list.
# There's one way to remove an item:

# Using the function del
del areas[8] # This will remove the item "garage" from the list, which is in the position 8.
del areas[8] # This will remove the item 12.0 from the list, which is in the position 8, because after removing "garage", the item 12.0 is now in the position 8.
print(areas) # by printing the list, it will show the updated version.
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'garage', 12.0]

# %%
# Functions: max()
nums = [3, 9, 23, 56, 81]
largest_number = max(nums) 
print(largest_number) # this will show the largest number in the list, which is 81.
# Out:
# 81

# %%
# Functions: round()
# The round() function rounds a number to a specified number of decimal places.
num = 3.14159
rounded_num = round(num, 2) # This will round the number to 2 decimal. (Italian: "arrotonda a 2 decimali")

# %%
# help()
# The help() function is used to get information about a specific function or module in Python.
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
# sorted()
# The sorted() function is used to customize the sort order, in a ascendent or descendent order. 
# This function is composed by two arguments: sorted(iterable, reverse=False)
# The first argument is the iterable/variable we want to sort, and we turn the reverse argument to True if we want to sort in a descent order, or False if we want an ascendent one.

ages = [21, 16, 54, 56, 25]

# Ascendent
ascendent_order = sorted(ages, reverse=False)
print(ascendent_order)

# Descent
descent_ages = sorted(ages, reverse=True)
print(descent_ages)
# Out:
# [14, 16, 25, 28, 56]
# [56, 28, 25, 16, 14]

# %%
# type()
# This function allows you to see which type of item you're working with, whether it's an integer, string, double, list, etc.
print(type(ages)) # This will show that the variable ages is a list.

switch = True
print(type(switch))
# Out:
# <class 'list'>
# <class 'bool'>

# %%
# Methods
# Methods are functions that are associated with a specific type of item, such as a string or else. They usually come with a dot after the item.

# .count() method counts the number of times a specific item appears in a list.

areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Print out how often 9.50 appears in areas
print(areas.count(9.50)) # it counts how many times the item 9.50 appears in the list areas, which is 1 time.
# Out:
# 1

# %%
# .index() - This method returns the index of the first occurrence of a specified value in a list.
print(areas.index(20.0)) # This will show the position of the item 20.0 in the list areas, which is 2, because it is in the position 2 of the list.

# %%
# .append() - This method adds an item to the end of the list.
ageS = [21, 16, 54, 56, 25]
ageS.append(44) # This will add the item 44 to the end of the list ageS.

print(ageS)
# Out:
# [21, 16, 54, 56, 25, 44]

# %%
# .remove() - It removes the first element of a list that matches the input.
ageS.remove(54) # This will remove the first occurrence of the item 54 from the list ageS.
print(ageS)
# Out:
# [21, 16, 56, 25, 44]

# %%
# .reverse() - It reverses the order of the elements in the list it is called on.
ageS.reverse()
print(ageS)
# Out:
# [44, 25, 56, 16, 21]

# %%
# Packages: math
# With this package, you can perform mathematical operations, such as calculating the square root of a number, or the value of pi, etc.
import math 

# With the math package, we can calculate the pi value, by using math.pi!

C = 2 * math.pi * 3 # we're calculating the value of a circunference, which is 2 * math.pi * r
# By inserting math.pi, this item calculates the value of a pi as an integer.
